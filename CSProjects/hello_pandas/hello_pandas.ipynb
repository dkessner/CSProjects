# %%
import pandas as pd

# %%
crime = pd.read_csv("Crime_Data_from_2020_to_Present.csv")

# %%
crime
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 559614  221213384  06/07/2022 12:00:00 AM  06/07/2022 12:00:00 AM      1900
# 559615  220314584  08/02/2022 12:00:00 AM  08/02/2022 12:00:00 AM        10
# 559616  221005507  02/10/2022 12:00:00 AM  02/09/2022 12:00:00 AM      1530
# 559617  221105477  02/10/2022 12:00:00 AM  02/08/2022 12:00:00 AM      2000
# 559618  221605448  02/15/2022 12:00:00 AM  02/14/2022 12:00:00 AM      1800
#
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559619 entries, 0 to 559618
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           559619 non-null  int64
#  1   Date Rptd       559619 non-null  object
#  2   DATE OCC        559619 non-null  object
#  3   TIME OCC        559619 non-null  int64
#  4   AREA            559619 non-null  int64
#  5   AREA NAME       559619 non-null  object
#  6   Rpt Dist No     559619 non-null  int64
#  7   Part 1-2        559619 non-null  int64
#  8   Crm Cd          559619 non-null  int64
#  9   Crm Cd Desc     559619 non-null  object
#  10  Mocodes         482136 non-null  object
#  11  Vict Age        559619 non-null  int64
#  12  Vict Sex        485536 non-null  object
#  13  Vict Descent    485531 non-null  object
#  14  Premis Cd       559614 non-null  float64
#  15  Premis Desc     559362 non-null  object
# ...

# %%
crimes = crime["Crm Cd Desc"]
locations = crime["LOCATION"]

# %%
crime[locations.str.contains("ROSSMORE")]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 5261    200700649  04/04/2020 12:00:00 AM  04/03/2020 12:00:00 AM      2300
# 5432    200714937  10/15/2020 12:00:00 AM  10/09/2020 12:00:00 AM      1700
# 7861    200707611  03/07/2020 12:00:00 AM  03/07/2020 12:00:00 AM       200
# 8915    200710419  06/13/2020 12:00:00 AM  06/13/2020 12:00:00 AM       930
# 8952    200715015  10/17/2020 12:00:00 AM  10/17/2020 12:00:00 AM      1900
# ...           ...                     ...                     ...       ...
# 547451  220712114  07/26/2022 12:00:00 AM  07/19/2022 12:00:00 AM      1300
# 547834  220707185  03/25/2022 12:00:00 AM  03/24/2022 12:00:00 AM      1710
# 553166  220708119  04/15/2022 12:00:00 AM  04/14/2022 12:00:00 AM      1240
# 554685  220707103  03/22/2022 12:00:00 AM  03/18/2022 12:00:00 AM      2355
# 556616  220708460  04/26/2022 12:00:00 AM  04/25/2022 12:00:00 AM      2100
#
#         AREA AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
rossmore_crimes = crime[locations.str.contains("ROSSMORE")]["Crm Cd Desc"]

# %%
rc = set(rossmore_crimes)
rc
# Out:
# {'ARSON',
#  'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#  'ATTEMPTED ROBBERY',
#  'BATTERY - SIMPLE ASSAULT',
#  'BATTERY WITH SEXUAL CONTACT',
#  'BIKE - STOLEN',
#  'BRANDISH WEAPON',
#  'BUNCO, GRAND THEFT',
#  'BURGLARY',
#  'BURGLARY FROM VEHICLE',
#  'BURGLARY, ATTEMPTED',
#  'CHILD NEGLECT (SEE 300 W.I.C.)',
#  'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#  'DISTURBING THE PEACE',
#  'DOCUMENT FORGERY / STOLEN FELONY',
#  'INTIMATE PARTNER - AGGRAVATED ASSAULT',
#  'INTIMATE PARTNER - SIMPLE ASSAULT',
#  'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#  'OTHER ASSAULT',
#  'PICKPOCKET',
#  'RAPE, FORCIBLE',
#  'ROBBERY',
#  'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#  'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
#  'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#  'THEFT OF IDENTITY',
#  'THEFT PLAIN - PETTY ($950 & UNDER)',
#  'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#  'THREATENING PHONE CALLS/LETTERS',
#  'TRESPASSING',
# ...
